# %% [markdown]
# <a href="https://colab.research.google.com/github/kayc0des/machine-learning_playbook/blob/main/binomial_distribution02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 14
p = 0.5

x = np.arange(0, n+1)
y = [np.math.comb(n, k) * (p**k) * ((1-p)**(n-k)) for k in x]

plt.fill_between(x, y, color='skyblue', alpha=0.5)
plt.grid(True)
plt.xlabel('x successes')
plt.ylabel('y = Probability Distribution')
plt.title("Binomial Distribution")
plt.show()
